# %%
import numpy as np
from numpy import log10
import pandas as pd
import matplotlib.pyplot as plt
from pywt import wavedec, waverec
from scipy.signal import lfilter
from sklearn.metrics import mean_squared_error

# %%
# Load the EEG signal dataset from a CSV file
eeg_data = pd.read_csv('eeg_data.csv')

# %%
signal = eeg_data['EEG.AF3'].values

# %%
# Plot the noisy signal
plt.figure()
plt.plot(signal)
plt.title('Original Signal')
# Out:
# Text(0.5, 1.0, 'Original Signal')

# %%
# Add Poisson noise to the signal
lambda_ = 5  # parameter of the Poisson distribution
noisy_signal = np.random.poisson(lambda_ * np.abs(signal)) * np.sign(signal)

# %%
# Plot the noisy signal
plt.figure()
plt.plot(noisy_signal)
plt.title('Noisy signal')
# Out:
# Text(0.5, 1.0, 'Noisy signal')

# %%
# Define the wavelet function and decomposition level
wavelet = 'db4'
level = 4

# Decompose the noisy signal using the wavelet transform
coeffs = wavedec(noisy_signal, wavelet, level=level)

# Set the threshold for coefficients
threshold = np.sqrt(2*np.log(len(noisy_signal)))

# Apply soft thresholding to the wavelet coefficients
thresholded_coeffs = [np.sign(c) * np.maximum(abs(c) - threshold, 0) for c in coeffs]

# Reconstruct the denoised signal from the thresholded coefficients
filtered_signal = waverec(thresholded_coeffs, wavelet)
filtered_signal = filtered_signal[:len(signal)]

# %%
mse = mean_squared_error(noisy_signal, filtered_signal)
psnr = 20 * log10(max(noisy_signal)) - 10 * log10(mse)
snr = 10 * log10(np.sum(noisy_signal**2) / np.sum((noisy_signal - filtered_signal)**2))

# %%
# Plot the original, noisy, and filtered signals
plt.figure(figsize=(10,2))
plt.plot(signal, label='Original signal')
plt.plot(noisy_signal, label='Noisy signal')
plt.plot(filtered_signal, label='Filtered signal')
plt.legend()
plt.show()

# Print the PSNR, MSE, and SNR values
print("PSNR:", psnr)
print("MSE:", mse)
print("SNR:", snr)
# Out:
# PSNR: 75.69707944463714
# MSE: 20.37435055473149
# SNR: 73.48951733883374

# %%
# Plot the original signal
plt.figure()
plt.plot(signal)
plt.title('Original signal')

# Plot the noisy signal
plt.figure()
plt.plot(noisy_signal)
plt.title('Noisy signal')

# Plot the filtered signal
plt.figure()
plt.plot(filtered_signal)
plt.title('Filtered signal')

# Show all the plots
plt.show()
